# %%
import polars as pl
from edges import combine, branch_count

# %%
df = combine()

# %%
df = df.with_columns(
        branch_count().alias('branch_count')
    )

# %%
df.filter()
# Out:
# shape: (5, 10)
# ┌────────────┬────────────┬────────────┬──────────┬───┬────────────┬─────────┬────────┬────────────┐
# │ _from      ┆ _to        ┆ from       ┆ to       ┆ … ┆ resembling ┆ type    ┆ branch ┆ branch_cou │
# │ ---        ┆ ---        ┆ ---        ┆ ---      ┆   ┆ ---        ┆ ---     ┆ ---    ┆ nt         │
# │ str        ┆ str        ┆ str        ┆ str      ┆   ┆ bool       ┆ str     ┆ str    ┆ ---        │
# │            ┆            ┆            ┆          ┆   ┆            ┆         ┆        ┆ u64        │
# ╞════════════╪════════════╪════════════╪══════════╪═══╪════════════╪═════════╪════════╪════════════╡
# │ super_nav_ ┆ super_nav_ ┆ an1.6-10   ┆ ea9.8    ┆ … ┆ false      ┆ full    ┆ main   ┆ 2          │
# │ details/an ┆ details/ea ┆            ┆          ┆   ┆            ┆         ┆        ┆            │
# │ 1.1-10     ┆ 9.8        ┆            ┆          ┆   ┆            ┆         ┆        ┆            │
# ...
