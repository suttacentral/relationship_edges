# %%
import polars as pl
from edges import combine, branch_count

# %%
df = combine()

# %%
df = df.with_columns(
        branch_count().alias('branch_count')
    )

# %%
df.describe()
# Out:
# shape: (9, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ _from     ┆ _to       ┆ from      ┆ … ┆ resemblin ┆ type      ┆ branch    ┆ branch_c │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ g         ┆ ---       ┆ ---       ┆ ount     │
# │ str       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ str       ┆ str       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆           ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 842196    ┆ 842196    ┆ 842196    ┆ … ┆ 842196.0  ┆ 842196    ┆ 842196    ┆ 842196.0 │
# │ null_coun ┆ 0         ┆ 0         ┆ 0         ┆ … ┆ 0.0       ┆ 0         ┆ 0         ┆ 0.0      │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...
