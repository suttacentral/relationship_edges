# %%
import polars as pl
from edges import combine, branch_count, in_both_branches

# %%
df = combine()

# %%
df = df.with_columns(
        in_both_branches(branch_count()).alias('in_both')
    )

# %%
df.filter(~pl.col('in_both'))
# Out:
# shape: (2_816, 10)
# ┌────────────┬────────────┬────────────┬───────────┬───┬───────────┬─────────┬───────────┬─────────┐
# │ _from      ┆ _to        ┆ from       ┆ to        ┆ … ┆ resemblin ┆ type    ┆ branch    ┆ in_both │
# │ ---        ┆ ---        ┆ ---        ┆ ---       ┆   ┆ g         ┆ ---     ┆ ---       ┆ ---     │
# │ str        ┆ str        ┆ str        ┆ str       ┆   ┆ ---       ┆ str     ┆ str       ┆ bool    │
# │            ┆            ┆            ┆           ┆   ┆ bool      ┆         ┆           ┆         │
# ╞════════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═════════╪═══════════╪═════════╡
# │ super_nav_ ┆ super_nav_ ┆ an1.219-23 ┆ ~mil5.5.3 ┆ … ┆ false     ┆ mention ┆ main      ┆ false   │
# │ details/an ┆ details/mi ┆ 4#1.1      ┆ #1.1      ┆   ┆           ┆         ┆           ┆         │
# │ 1.219-234  ┆ l5.5.3     ┆            ┆           ┆   ┆           ┆         ┆           ┆         │
# ...
